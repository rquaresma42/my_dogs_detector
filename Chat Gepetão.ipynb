# %% [markdown]
# # <font color='blue'>Dog Detector</font>
#
# Problema de Negócio:
#
# Construir um modelo de Inteligência Artificial capaz de classificar imagens considerando 3 categorias, sendo os meus cachorros. Dada uma nova imagem de uma dessas categorias o modelo deve ser capaz de classificar e indicar o que é a imagem.

# %%
# Silencia mensagens do TF
# %env TF_CPP_MIN_LOG_LEVEL=3
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3

# %%
# Imports
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import os
import PIL
from PIL import Image
#PreTrained Model
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import datasets, layers, models
from keras.layers import *
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

# %% [markdown]
# ## Carregando os Dados do disco

# %%
# Substitua pelo caminho local do seu arquivo ZIP
data_dir = "C:/Users/rafae/OneDrive/Documents/DeepLearning/MyDogs Detector/data/dogs"

data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 195

# %% [markdown]
# ### Parâmetros

# %%
batch_size = 64
img_height = 224
img_width = 224

# %% [markdown]
# ### Criaçao do dataset de treino

# %%
treino_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 195 files belonging to 3 classes.
# Using 137 files for training.

# %% [markdown]
# ### Criação do dataset de Teste

# %%
teste_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 195 files belonging to 3 classes.
# Using 58 files for validation.

# %%
nomes_classes = ['kiara','rex','rocky']
print(nomes_classes)
# Out:
# ['kiara', 'rex', 'rocky']

# %%
plt.figure(figsize=(10, 10))
for images, labels in treino_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(nomes_classes[labels[i]])
    plt.axis("off")

# %%
imagens_treino = []
labels_treino = []

for images, labels in treino_ds.take(1):
    imagens_treino.append(images.numpy().astype("uint8"))
    labels_treino.append(labels.numpy().astype("int"))

# %%
labels_treino = labels_treino[0]

# %%
imagens_treino = imagens_treino[0]

# %%
print(labels_treino)
print(imagens_treino)
# Out:
# [2 2 0 1 1 0 0 2 2 0 1 1 0 1 2 0 1 0 2 0 1 2 2 0 2 2 2 2 0 1 2 0 1 0 1 0 1
#  2 0 0 0 1 0 2 1 2 1 1 2 2 2 2 0 2 0 0 0 2 1 0 0 1 1 1]
# [[[[150 160 161]
#    [152 161 160]
#    [147 157 158]
#    ...
#    [ 30  34  37]
#    [ 25  30  33]
#    [ 34  38  41]]
#
#   [[146 156 158]
#    [151 161 162]
#    [149 159 160]
#    ...
#    [ 29  30  34]
#    [ 30  31  33]
#    [ 32  32  34]]
#
#   [[145 156 158]
#    [150 160 162]
#    [151 159 162]
#    ...
#    [ 26  30  33]
#    [ 29  31  30]
#    [ 30  31  33]]
#
#   ...
#
#   [[ 54  41  33]
#    [ 53  40  31]
#    [ 53  40  32]
#    ...
#    [  0   1   0]
#    [  0   1   0]
#    [  0   1   0]]
#
#   [[ 51  38  32]
#    [ 50  37  29]
#    [ 51  38  30]
#    ...
#    [  0   1   0]
#    [  0   1   0]
#    [  0   1   0]]
#
#   [[ 43  33  24]
#    [ 49  39  30]
#    [ 52  38  29]
#    ...
#    [  0   1   0]
#    [  0   1   0]
#    [  0   1   0]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [145 138 130]
#    [147 140 132]
#    [148 139 134]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [148 141 133]
#    [146 139 131]
#    [150 142 139]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [149 142 134]
#    [147 140 132]
#    [146 141 135]]
#
#   ...
#
#   [[126 108  86]
#    [135 114  93]
#    [133 112  91]
#    ...
#    [  9   9   9]
#    [ 11  11  11]
#    [ 15  14  12]]
#
#   [[136 114  90]
#    [135 113  89]
#    [135 113  92]
#    ...
#    [  5   9   8]
#    [ 10  12  12]
#    [ 14  16  15]]
#
#   [[136 115  94]
#    [133 112  91]
#    [132 111  90]
#    ...
#    [  8   9  11]
#    [  8   9  11]
#    [ 14  16  15]]]
#
#
#  [[[129 135 125]
#    [119 129 118]
#    [120 128 117]
#    ...
#    [ 98  53  15]
#    [ 52  34  12]
#    [ 44  32  10]]
#
#   [[130 137 127]
#    [121 128 120]
#    [122 129 121]
#    ...
#    [ 62  41  19]
#    [ 54  33  12]
#    [ 47  29   7]]
#
#   [[125 132 124]
#    [127 134 126]
#    [128 135 127]
#    ...
#    [ 63  37  20]
#    [ 55  34  15]
#    [ 52  30   9]]
#
#   ...
#
#   [[159 163 162]
#    [158 162 163]
#    [161 165 166]
#    ...
#    [ 18  18  18]
#    [ 25  21  22]
#    [ 23  19  18]]
#
#   [[152 156 155]
#    [160 164 165]
#    [159 163 164]
#    ...
#    [ 30  30  30]
#    [ 20  18  19]
#    [ 15  14  12]]
#
#   [[157 162 158]
#    [156 160 159]
#    [157 163 163]
#    ...
#    [ 29  29  27]
#    [ 18  18  17]
#    [ 14  16  13]]]
#
#
#  ...
#
#
#  [[[169 167 168]
#    [165 163 166]
#    [160 161 163]
#    ...
#    [ 86  88  85]
#    [ 79  84  80]
#    [ 88  92  93]]
#
#   [[165 169 172]
#    [163 164 166]
#    [157 158 162]
#    ...
#    [ 82  82  80]
#    [ 80  80  80]
#    [ 83  83  83]]
#
#   [[161 165 168]
#    [160 159 164]
#    [165 166 170]
#    ...
#    [ 77  77  75]
#    [ 83  81  82]
#    [ 80  79  77]]
#
#   ...
#
#   [[186 186 188]
#    [184 183 181]
#    [175 175 175]
#    ...
#    [178 176 179]
#    [176 174 179]
#    [188 186 187]]
#
#   [[158 156 157]
#    [190 186 187]
#    [176 175 173]
#    ...
#    [186 185 190]
#    [162 161 166]
#    [162 163 165]]
#
#   [[137 135 136]
#    [185 184 182]
#    [197 193 190]
#    ...
#    [192 193 195]
#    [197 198 200]
#    [224 222 223]]]
#
#
#  [[[207 203 111]
#    [168 179  97]
#    [199 203 140]
#    ...
#    [168 184 199]
#    [179 195 210]
#    [ 97 113 136]]
#
#   [[126 160  26]
#    [148 182  77]
#    [231 245 153]
#    ...
#    [162 178 192]
#    [164 180 195]
#    [120 131 155]]
#
#   [[132 207   2]
#    [133 191  53]
#    [142 179  67]
#    ...
#    [168 185 201]
#    [163 176 192]
#    [129 139 166]]
#
#   ...
#
#   [[225 230 233]
#    [227 230 235]
#    [230 233 238]
#    ...
#    [191 198  96]
#    [198 206  75]
#    [230 231  89]]
#
#   [[226 230 233]
#    [231 236 239]
#    [240 244 246]
#    ...
#    [231 249 133]
#    [238 252  93]
#    [255 254 102]]
#
#   [[222 227 231]
#    [228 232 235]
#    [233 237 240]
#    ...
#    [245 237 159]
#    [203 195  70]
#    [185 173   3]]]
#
#
#  [[[152 134 132]
#    [124 108 105]
#    [235 222 216]
#    ...
#    [233 176 133]
#    [217 159 123]
#    [130  74  59]]
#
#   [[169 149 148]
#    [126 108 106]
#    [220 206 203]
#    ...
#    [234 177 134]
#    [217 161 129]
#    [128  72  59]]
#
#   [[149 129 128]
#    [126 106 105]
#    [189 174 169]
#    ...
#    [231 173 135]
#    [202 142 115]
#    [134  78  63]]
#
#   ...
#
#   [[ 71  37  36]
#    [ 83  52  49]
#    [ 89  58  53]
#    ...
#    [184 174 172]
#    [184 174 172]
#    [184 174 172]]
#
#   [[ 85  54  51]
#    [ 85  57  51]
#    [ 89  60  54]
#    ...
#    [184 174 172]
#    [184 174 172]
#    [184 174 172]]
#
#   [[ 94  60  58]
#    [ 89  61  54]
#    [ 95  66  60]
#    ...
#    [187 177 175]
#    [186 176 174]
#    [184 174 172]]]]

# %%
imagens_teste = []
labels_teste = []

for images, labels in teste_ds.take(1):
    imagens_teste.append(images.numpy().astype("uint8"))
    labels_teste.append(labels.numpy().astype("uint8"))

# %%
imagens_teste = imagens_teste[0]
labels_teste = labels_teste[0]

# %% [markdown]
# ## Pré-Processamento e Visualização das Imagens

# %%
# Normaliza os valores dos pixels para que os dados fiquem na mesma escala
imagens_treino = imagens_treino / 255.0
imagens_teste = imagens_teste / 255.0

# %%
# Função para exibir as imagens
def visualiza_imagens(images, labels):
    plt.figure(figsize = (10,10))
    for i in range(25):
        plt.subplot(5, 5, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap = plt.cm.binary)
        plt.xlabel(nomes_classes[labels[i]])
    plt.show()

# %%
# Executa a função
visualiza_imagens(imagens_treino, labels_treino)

# %% [markdown]
# ## Construção do Modelo

# %%
def M_B(M_name,Base ,EPO, Drop_Val,A_Func,NUM_CLASS,imagens_treino,labels_treino):
    # Define the name for your model
    model_name = M_name
    # Build the model
    model = models.Sequential(name=model_name)

    # Add the pre-trained DenseNet121_base 
    model.add(Base)

    # Batch Normalization
    model.add(BatchNormalization())

    # Dropout 
    model.add(Dropout(Drop_Val))

    # Add a dense layer with 220 units and ReLU activation function
    model.add(Dense(50, activation='relu'))

    # Add the output layer with 10 units and Softmax activation function
    model.add(Dense(NUM_CLASS, activation=A_Func))

    # Compile
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Build the model
    model.build((None, img_height, img_width, 3))

    # Print model summary
    print(model.summary())
    
    #Early_Stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    #Fitting Model
    history = model.fit(imagens_treino, labels_treino,
                            epochs= EPO,
                            validation_data = (imagens_teste, labels_teste),
                            callbacks = early_stopping)
    
    return history, model

# %%
# # Define the URL of the model
# url = "https://tfhub.dev/google/bit/m-r50x1/1"

# # Load the model from the URL
# model_E = hub.KerasLayer(url)

# # Set the model to be non-trainable
# model_E.trainable = False

# Load the pre-trained DenseNet121 model without the top classification layer
DenseNet121_base = DenseNet121(weights='imagenet',
                                    include_top=False, 
                                   input_shape=(img_height, img_width,3),
                                     pooling = 'avg'
                                   )

# Freeze the pre-trained base model layers
DenseNet121_base.trainable = False

# %%
# Train Model
history , model = M_B("Gepetao_Model",
              DenseNet121_base,
              50,
              0.25,
              'softmax',
              3,
            imagens_treino,labels_treino)
# Out:
# Model: "Gepetao_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 50)                51250
#
#  dense_3 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 7,093,003
# Trainable params: 53,451
# Non-trainable params: 7,039,552
# _________________________________________________________________
# None
# Epoch 1/50
# 2/2 [==============================] - 11s 5s/step - loss: 1.4463 - accuracy: 0.2969 - val_loss: 1.4160 - val_accuracy: 0.2759
# Epoch 2/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.7793 - accuracy: 0.6719 - val_loss: 1.1064 - val_accuracy: 0.3621
# Epoch 3/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.4347 - accuracy: 0.8750 - val_loss: 0.8661 - val_accuracy: 0.5690
# Epoch 4/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.2661 - accuracy: 0.9375 - val_loss: 0.7024 - val_accuracy: 0.6552
# Epoch 5/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.1675 - accuracy: 0.9844 - val_loss: 0.5892 - val_accuracy: 0.7414
# Epoch 6/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.1227 - accuracy: 0.9688 - val_loss: 0.5126 - val_accuracy: 0.7759
# Epoch 7/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0956 - accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.8793
# Epoch 8/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.4234 - val_accuracy: 0.8966
# Epoch 9/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.3990 - val_accuracy: 0.8966
# Epoch 10/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.3816 - val_accuracy: 0.8966
# Epoch 11/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.3695 - val_accuracy: 0.8966
# Epoch 12/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.3606 - val_accuracy: 0.8793
# Epoch 13/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.3535 - val_accuracy: 0.8793
# Epoch 14/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.3471 - val_accuracy: 0.8793
# Epoch 15/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.8793
# Epoch 16/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.3371 - val_accuracy: 0.8621
# Epoch 17/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.3326 - val_accuracy: 0.8621
# Epoch 18/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.3284 - val_accuracy: 0.8621
# Epoch 19/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.3247 - val_accuracy: 0.8621
# Epoch 20/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.3212 - val_accuracy: 0.8793
# Epoch 21/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.3187 - val_accuracy: 0.8793
# Epoch 22/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.3160 - val_accuracy: 0.8793
# Epoch 23/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.3128 - val_accuracy: 0.8793
# Epoch 24/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.8793
# Epoch 25/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.3067 - val_accuracy: 0.8793
# Epoch 26/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.3041 - val_accuracy: 0.8966
# Epoch 27/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3015 - val_accuracy: 0.8966
# Epoch 28/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2987 - val_accuracy: 0.8966
# Epoch 29/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2962 - val_accuracy: 0.8966
# Epoch 30/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2942 - val_accuracy: 0.8966
# Epoch 31/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2925 - val_accuracy: 0.8966
# Epoch 32/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2911 - val_accuracy: 0.8966
# Epoch 33/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2900 - val_accuracy: 0.8966
# Epoch 34/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2889 - val_accuracy: 0.8966
# Epoch 35/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.8966
# Epoch 36/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2869 - val_accuracy: 0.8966
# Epoch 37/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2861 - val_accuracy: 0.8966
# Epoch 38/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.8966
# Epoch 39/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2841 - val_accuracy: 0.8966
# Epoch 40/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2830 - val_accuracy: 0.8966
# Epoch 41/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2821 - val_accuracy: 0.8966
# Epoch 42/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.8966
# Epoch 43/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.8966
# Epoch 44/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2796 - val_accuracy: 0.8966
# Epoch 45/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.8966
# Epoch 46/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.8966
# Epoch 47/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2777 - val_accuracy: 0.8966
# Epoch 48/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2771 - val_accuracy: 0.8966
# Epoch 49/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2764 - val_accuracy: 0.8966
# Epoch 50/50
# 2/2 [==============================] - 5s 4s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2755 - val_accuracy: 0.8966

# %%
# Avalia o modelo
erro_teste, acc_teste = model.evaluate(imagens_teste, labels_teste, verbose = 2)
# Out:
# 2/2 - 2s - loss: 0.2755 - accuracy: 0.8966 - 2s/epoch - 1s/step

# %%
print('\nAcurácia com Dados de Teste:', acc_teste)
# Out:
# Acurácia com Dados de Teste: 0.8965517282485962

# %% [markdown]
# ## Deploy do Modelo

# %%
# Carrega uma nova imagem
nova_imagem = Image.open("data/previsao/img1.jpg")

# Dimensões da imagem (em pixels)
nova_imagem.size

# Obtém largura e altura da imagem
largura = nova_imagem.width
altura = nova_imagem.height

print("A largura da imagem é: ", largura)
print("A altura da imagem é: ", altura)

# Redimensiona para 224 x 224 pixels
nova_imagem = nova_imagem.resize((img_height, img_width))

# Exibir a imagem
plt.figure(figsize = (10,10))
plt.imshow(nova_imagem)
plt.xticks([])
plt.yticks([])
plt.show()

# Converte a imagem para um array NumPy e normaliza
nova_imagem_array = np.array(nova_imagem) / 255.0

# Expande a dimensão do array para que ele tenha o formato (1, 32, 32, 3)
nova_imagem_array = np.expand_dims(nova_imagem_array, axis = 0)
# Out:
# A largura da imagem é:  4000
# A altura da imagem é:  2250

# %%
# Previsões
previsoes = model.predict(nova_imagem_array)
print(previsoes)

# Obtém a classe com maior probabilidade e o nome da classe
classe_prevista = np.argmax(previsoes)
nome_classe_prevista = nomes_classes[classe_prevista]

print("A nova imagem foi classificada como:", nome_classe_prevista.upper())
# Out:
# 1/1 [==============================] - 0s 86ms/step
# [[2.4371839e-03 1.6634857e-04 9.9739647e-01]]
# A nova imagem foi classificada como: ROCKY

# %% [markdown]
# # Fim
